# %%
import pandas as pd

xl = "C:\\Users\\zachi\\Desktop\\final_project_22\\data_nov_21.xlsx"

def clean_data (xl,month):
    
    df=pd.read_excel(xl)
        #Remove unnecessary column - "removed 1"

    df.drop(columns=['Removed 1'],inplace=True)

    #Make the Category column easier to understand 

    df=df.replace({'Category' : { 'Y' : "Antisemitic", 'W' : "Non-Antisemitic", 'U' : "Anti-Zionist" }})

    
    #Fix the Summary column's text

    df = df.replace(r'\n',' ', regex=True) 

    posts_description = df["A short summary of the content- write briefly in your own words "]


    #get rid of NaNs in category

    list = ["Anti-Zionist",
    "Antisemitic",
    "Non-Antisemitic"]

    df = df.loc[df['Category'] .isin(list)]

    #Convert "time stamp" to english

    df = df.rename(columns={"חותמת זמן":"Time stamp"})

        #Change the date time to the d/m/y
    from datetime import datetime
    df['Time stamp'] = pd.to_datetime(df['Time stamp']).dt.date #This function convert the date text into dt.date type
    month = 'November'


    new_df = df[pd.to_datetime(df["Time stamp"]).dt.strftime('%B') == month]


    return new_df

clean_data(xl,'November')
# Out:
#         Category      Removed  Time stamp First name Last (family) name  \
# 33   Antisemitic  Not Removed  2021-11-01      Irena             Kalika
# 34   Antisemitic  Not Removed  2021-11-01      Irena             Kalika
# 35   Antisemitic  Not Removed  2021-11-01      Irena             Kalika
# 36   Antisemitic  Not Removed  2021-11-01      Irena             Kalika
# 37   Antisemitic  Not Removed  2021-11-01      Irena             Kalika
# ..           ...          ...         ...        ...                ...
# 305  Antisemitic  Not Removed  2021-11-30       Liam            Menache
# 306  Antisemitic  Not Removed  2021-11-30       Liam            Menache
# 307  Antisemitic  Not Removed  2021-11-30      Irena             Kalika
# 308  Antisemitic  Not Removed  2021-11-30      Irena             Kalika
# 309  Antisemitic  Not Removed  2021-11-30      Irena             Kalika
#
#     Platform Language                                      Content Link   \
# 33        VK  Russian                https://vk.com/wall-112847027_96062
# 34        VK  Russian                https://vk.com/wall-112847027_96029
# 35        VK  Russian                https://vk.com/wall-112847027_96028
# 36   Twitter  English  https://twitter.com/Julie96136710/status/13076...
# 37   Twitter  English  https://twitter.com/SmirkCmdr9000/status/98426...
# ..       ...      ...                                                ...
# 305  Twitter  English  https://twitter.com/Frontlet_615/status/144970...
# 306  Twitter  English  https://twitter.com/EmpyUnplugged/status/14276...
# 307  Twitter  English  https://twitter.com/being_khan1010/status/1301...
# 308  Twitter  English  https://twitter.com/miraquib0072/status/139237...
# 309  Twitter  Russian  https://twitter.com/kosmo2213/status/108292324...
#
#     Other language?  Please specify below. Reported?  \
# 33                                     NaN       Yes
# 34                                     NaN       Yes
# 35                                     NaN       Yes
# 36                                     NaN       Yes
# 37                                     NaN       Yes
# ..                                     ...       ...
# 305                       French and Dutch       NaN
# 306                                    NaN       NaN
# 307                                    NaN       NaN
# 308                                    NaN       NaN
# 309                                    NaN       NaN
#
#              Please upload a screenshot of the content  \
# 33   https://drive.google.com/open?id=1dbOuCahgOpZ7...
# 34   https://drive.google.com/open?id=1sxMEVx2J5MdJ...
# 35   https://drive.google.com/open?id=141zUh8FxcS_I...
# 36   https://drive.google.com/open?id=1yLq9LCFV3NHi...
# 37   https://drive.google.com/open?id=19mxAL7Zs8eOB...
# ..                                                 ...
# 305  https://drive.google.com/open?id=1f9WNsyE6fxGw...
# 306  https://drive.google.com/open?id=1eF-_3YcYwPFC...
# 307  https://drive.google.com/open?id=1ahaRnRopBHQw...
# 308  https://drive.google.com/open?id=1oTmP02zaBsk0...
# 309  https://drive.google.com/open?id=1eBYbOYTPeEdi...
#
#     A short summary of the content- write briefly in your own words   \
# 33   "there is no word "conscience" in torah meanin...
# 34   "Jews cannot fight, they can only hold their c...
# 35   Claiming that fascism and antisemitism were in...
# 36                              Jews control the world
# 37                                    Holocaust denial
# ..                                                 ...
# 305  User claims a quote by a rabbi that the jews w...
# 306  Says that other than the "holohaux" which is h...
# 307  Claiming that us trying to make Muslims inferi...
# 308    Promote Natzism and genocide of jews. #killjews
# 309    Accusing jews in genocide of indians in America
#
#              Email address         Country where content published  \
# 33   irakalika85@gmail.com                                 Unknown
# 34   irakalika85@gmail.com                                 Unknown
# 35   irakalika85@gmail.com                                 Unknown
# 36   irakalika85@gmail.com                                 Unknown
# 37   irakalika85@gmail.com                                 Unknown
# ..                     ...                                     ...
# 305     liam8110@gmail.com                          European Union
# 306     liam8110@gmail.com                          United Kingdom
# 307  irakalika85@gmail.com  Asia (for example: Pakistan, India...)
# 308  irakalika85@gmail.com                                 Unknown
# 309  irakalika85@gmail.com                                 Unknown
#
#      Age of user
# 33           NaN
# 34           NaN
# 35           NaN
# 36           NaN
# 37           NaN
# ..           ...
# 305          NaN
# 306          NaN
# 307          NaN
# 308          NaN
# 309          NaN
#
# [250 rows x 15 columns]

# %%
df = df=pd.read_excel("C:\\Users\\zachi\\Desktop\\final_project_22\\data_nov_21.xlsx")
df = df.rename(columns={"חותמת זמן":"Time stamp"})

    #Change the date time to the d/m/y
from datetime import datetime
df['Time stamp'] = pd.to_datetime(df['Time stamp']).dt.date #This function convert the date text into dt.date type
user_input = 'November'


#the_user_target_date = df["Time stamp"]>df["Time stamp"].dt.strftime('%B') == user_input
#new_df = df[the_user_target_date]

new_df = df[pd.to_datetime(df["Time stamp"]).dt.strftime('%B') == user_input]
# Out:
#     Category      Removed  Removed 1  Time stamp First name  \
# 33         Y  Not Removed        NaN  2021-11-01      Irena
# 34         Y  Not Removed        NaN  2021-11-01      Irena
# 35         Y  Not Removed        NaN  2021-11-01      Irena
# 36         Y  Not Removed        NaN  2021-11-01      Irena
# 37         Y  Not Removed        NaN  2021-11-01      Irena
# ..       ...          ...        ...         ...        ...
# 305        Y  Not Removed        NaN  2021-11-30       Liam
# 306        Y  Not Removed        NaN  2021-11-30       Liam
# 307        Y  Not Removed        NaN  2021-11-30      Irena
# 308        Y  Not Removed        NaN  2021-11-30      Irena
# 309        Y  Not Removed        NaN  2021-11-30      Irena
#
#     Last (family) name Platform Language  \
# 33              Kalika       VK  Russian
# 34              Kalika       VK  Russian
# 35              Kalika       VK  Russian
# 36              Kalika  Twitter  English
# 37              Kalika  Twitter  English
# ..                 ...      ...      ...
# 305            Menache  Twitter  English
# 306            Menache  Twitter  English
# 307             Kalika  Twitter  English
# 308             Kalika  Twitter  English
# 309             Kalika  Twitter  Russian
#
#                                          Content Link   \
# 33                 https://vk.com/wall-112847027_96062
# 34                 https://vk.com/wall-112847027_96029
# 35                 https://vk.com/wall-112847027_96028
# 36   https://twitter.com/Julie96136710/status/13076...
# 37   https://twitter.com/SmirkCmdr9000/status/98426...
# ..                                                 ...
# 305  https://twitter.com/Frontlet_615/status/144970...
# 306  https://twitter.com/EmpyUnplugged/status/14276...
# 307  https://twitter.com/being_khan1010/status/1301...
# 308  https://twitter.com/miraquib0072/status/139237...
# 309  https://twitter.com/kosmo2213/status/108292324...
#
#     Other language?  Please specify below. Reported?  \
# 33                                     NaN       Yes
# 34                                     NaN       Yes
# 35                                     NaN       Yes
# 36                                     NaN       Yes
# 37                                     NaN       Yes
# ..                                     ...       ...
# 305                       French and Dutch       NaN
# 306                                    NaN       NaN
# 307                                    NaN       NaN
# 308                                    NaN       NaN
# 309                                    NaN       NaN
#
#              Please upload a screenshot of the content  \
# 33   https://drive.google.com/open?id=1dbOuCahgOpZ7...
# 34   https://drive.google.com/open?id=1sxMEVx2J5MdJ...
# 35   https://drive.google.com/open?id=141zUh8FxcS_I...
# 36   https://drive.google.com/open?id=1yLq9LCFV3NHi...
# 37   https://drive.google.com/open?id=19mxAL7Zs8eOB...
# ..                                                 ...
# 305  https://drive.google.com/open?id=1f9WNsyE6fxGw...
# 306  https://drive.google.com/open?id=1eF-_3YcYwPFC...
# 307  https://drive.google.com/open?id=1ahaRnRopBHQw...
# 308  https://drive.google.com/open?id=1oTmP02zaBsk0...
# 309  https://drive.google.com/open?id=1eBYbOYTPeEdi...
#
#     A short summary of the content- write briefly in your own words   \
# 33   "there is no word "conscience" in torah meanin...
# 34   "Jews cannot fight, they can only hold their c...
# 35   Claiming that fascism and antisemitism were in...
# 36                              Jews control the world
# 37                                    Holocaust denial
# ..                                                 ...
# 305  User claims a quote by a rabbi that the jews w...
# 306  Says that other than the "holohaux" which is h...
# 307  Claiming that us trying to make Muslims inferi...
# 308    Promote Natzism and genocide of jews. #killjews
# 309    Accusing jews in genocide of indians in America
#
#              Email address         Country where content published  \
# 33   irakalika85@gmail.com                                 Unknown
# 34   irakalika85@gmail.com                                 Unknown
# 35   irakalika85@gmail.com                                 Unknown
# 36   irakalika85@gmail.com                                 Unknown
# 37   irakalika85@gmail.com                                 Unknown
# ..                     ...                                     ...
# 305     liam8110@gmail.com                          European Union
# 306     liam8110@gmail.com                          United Kingdom
# 307  irakalika85@gmail.com  Asia (for example: Pakistan, India...)
# 308  irakalika85@gmail.com                                 Unknown
# 309  irakalika85@gmail.com                                 Unknown
#
#      Age of user
# 33           NaN
# 34           NaN
# 35           NaN
# 36           NaN
# 37           NaN
# ..           ...
# 305          NaN
# 306          NaN
# 307          NaN
# 308          NaN
# 309          NaN
#
# [277 rows x 16 columns]
